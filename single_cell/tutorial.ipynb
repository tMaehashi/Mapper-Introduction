# %% [markdown]
# # Mapper チュートリアル

# %%
import pandas as pd
import matplotlib.pyplot as plt
import japanize_matplotlib
import numpy as np

# %% [markdown]
# ## 読み込み・前処理
# log2{FPKM+1}

# %%
data = pd.read_csv('Trapnell.csv', index_col=0)
data = np.log2(data+1)
print(data.shape)
data.head()
# Out:
# (372, 47192)
#            ENSG00000000003  ENSG00000000005  ENSG00000000419  ENSG00000000457
# T0_CT_A01         4.522583              0.0         5.359651         0.953884  \
# T0_CT_A02         3.020881              0.0         5.819167         0.711520
# T0_CT_A03         1.189059              0.0         6.296105         0.790101
# T0_CT_A04         4.364719              0.0         6.291769         3.744968
# T0_CT_A05         5.474494              0.0         2.906229         0.000000
#
#            ENSG00000000460  ENSG00000000938  ENSG00000000971  ENSG00000001036
# T0_CT_A01         0.799852              0.0         2.001074         7.013429  \
# T0_CT_A02         1.266331              0.0         2.045971         5.393042
# T0_CT_A03         5.872299              0.0         4.027012         4.094802
# T0_CT_A04         3.672606              0.0         0.000000         5.145494
# T0_CT_A05         2.303304              0.0         5.695014         4.718137
#
#            ENSG00000001084  ENSG00000001167  ...  ENSGR0000234622
# T0_CT_A01         3.107641         3.809919  ...              0.0  \
# T0_CT_A02         5.883117         0.544750  ...              0.0
# T0_CT_A03         0.000000         4.688046  ...              0.0
# T0_CT_A04         0.000000         4.321041  ...              0.0
# T0_CT_A05         0.000000         0.749671  ...              0.0
#
#            ENSGR0000234958  ENSGR0000236017  ENSGR0000236871  ENSGR0000237040
# T0_CT_A01              0.0              0.0              0.0              0.0  \
# T0_CT_A02              0.0              0.0              0.0              0.0
# T0_CT_A03              0.0              0.0              0.0              0.0
# T0_CT_A04              0.0              0.0              0.0              0.0
# T0_CT_A05              0.0              0.0              0.0              0.0
#
#            ENSGR0000237531  ENSGR0000237801  ENSGR0000248421  ENSGR0000249358
# T0_CT_A01              0.0              0.0              0.0              0.0  \
# T0_CT_A02              0.0              0.0              0.0              0.0
# T0_CT_A03              0.0              0.0              0.0              0.0
# T0_CT_A04              0.0              0.0              0.0              0.0
# T0_CT_A05              0.0              0.0              0.0              0.0
#
#            ENSGR0000270726
# T0_CT_A01              0.0
# T0_CT_A02              0.0
# T0_CT_A03              0.0
# T0_CT_A04              0.0
# T0_CT_A05              0.0
#
# [5 rows x 47192 columns]

# %% [markdown]
# ## 遺伝子リスト

# %%
# 重要遺伝子20個抽出
df = data.loc[:, ['ENSG00000081189', 'ENSG00000116604', 'ENSG00000111049', 'ENSG00000166825',\
               'ENSG00000134853', 'ENSG00000122180', 'ENSG00000140416', 'ENSG00000198467',\
               'ENSG00000125414', 'ENSG00000109063', 'ENSG00000149294', 'ENSG00000105048',\
               'ENSG00000118194', 'ENSG00000114854', 'ENSG00000170312', 'ENSG00000123374',\
               'ENSG00000134057', 'ENSG00000157456', 'ENSG00000110092', 'ENSG00000125968'
               ]]
df.head()
# Out:
#            ENSG00000081189  ENSG00000116604  ENSG00000111049  ENSG00000166825
# T0_CT_A01         1.064069          0.00000         6.856774         4.519202  \
# T0_CT_A02         0.000000          0.00000         2.062705         3.524791
# T0_CT_A03         3.845289          0.59788         8.109914         3.215826
# T0_CT_A04         2.571388          0.00000         6.038441         5.526182
# T0_CT_A05         7.459727          0.00000         7.586600         0.647364
#
#            ENSG00000134853  ENSG00000122180  ENSG00000140416  ENSG00000198467
# T0_CT_A01         0.000000         0.000000         7.642759         8.087017  \
# T0_CT_A02         0.000000         0.000000         5.902768         7.959979
# T0_CT_A03         0.069637         0.000000         7.681843         8.658072
# T0_CT_A04         0.000000         0.000000         6.489623         7.234453
# T0_CT_A05         0.000000         0.816478         7.629109         7.754547
#
#            ENSG00000125414  ENSG00000109063  ENSG00000149294  ENSG00000105048
# T0_CT_A01         0.000000         0.000000         0.339402          0.00000  \
# T0_CT_A02         0.000000         0.000000         2.371528          0.00000
# T0_CT_A03         0.000000         0.076072         3.871696          0.00000
# T0_CT_A04         0.000000         0.000000         5.469391          0.00000
# T0_CT_A05         3.344181         0.000000         5.447387          4.37337
#
#            ENSG00000118194  ENSG00000114854  ENSG00000170312  ENSG00000123374
# T0_CT_A01         4.674093              0.0         3.947339         0.258707  \
# T0_CT_A02         0.000000              0.0         7.588002         0.485545
# T0_CT_A03         4.844461              0.0         7.241373         1.050146
# T0_CT_A04         5.485292              0.0         6.851424         2.086930
# T0_CT_A05         7.664006              0.0         8.080381         3.358793
#
#            ENSG00000134057  ENSG00000157456  ENSG00000110092  ENSG00000125968
# T0_CT_A01         4.742012         4.299699         5.631774         4.635093
# T0_CT_A02         7.405678         7.289281         5.758634         6.385429
# T0_CT_A03         6.129029         7.247890         4.542797         7.135330
# T0_CT_A04         9.411894         8.073290         3.591105         3.811132
# T0_CT_A05         6.073090         7.089435         4.746001         0.000000

# %%
genes = ['MEF2C', 'MEF2D', 'MYF5', 'ANPEP', 'PDGFRA', 'MYOG', 'TPM1', 'TPM2',\
         'MYH2', 'MYH3', 'NCAM1', 'TNNT1', 'TNNT2', 'TNNC1', 'CDK1', 'CDK2',\
         'CCNB1', 'CCNB2', 'CCND1', 'ID1']

df.columns = genes
df.head()
# Out:
#               MEF2C    MEF2D      MYF5     ANPEP    PDGFRA      MYOG
# T0_CT_A01  1.064069  0.00000  6.856774  4.519202  0.000000  0.000000  \
# T0_CT_A02  0.000000  0.00000  2.062705  3.524791  0.000000  0.000000
# T0_CT_A03  3.845289  0.59788  8.109914  3.215826  0.069637  0.000000
# T0_CT_A04  2.571388  0.00000  6.038441  5.526182  0.000000  0.000000
# T0_CT_A05  7.459727  0.00000  7.586600  0.647364  0.000000  0.816478
#
#                TPM1      TPM2      MYH2      MYH3     NCAM1    TNNT1
# T0_CT_A01  7.642759  8.087017  0.000000  0.000000  0.339402  0.00000  \
# T0_CT_A02  5.902768  7.959979  0.000000  0.000000  2.371528  0.00000
# T0_CT_A03  7.681843  8.658072  0.000000  0.076072  3.871696  0.00000
# T0_CT_A04  6.489623  7.234453  0.000000  0.000000  5.469391  0.00000
# T0_CT_A05  7.629109  7.754547  3.344181  0.000000  5.447387  4.37337
#
#               TNNT2  TNNC1      CDK1      CDK2     CCNB1     CCNB2     CCND1
# T0_CT_A01  4.674093    0.0  3.947339  0.258707  4.742012  4.299699  5.631774  \
# T0_CT_A02  0.000000    0.0  7.588002  0.485545  7.405678  7.289281  5.758634
# T0_CT_A03  4.844461    0.0  7.241373  1.050146  6.129029  7.247890  4.542797
# T0_CT_A04  5.485292    0.0  6.851424  2.086930  9.411894  8.073290  3.591105
# T0_CT_A05  7.664006    0.0  8.080381  3.358793  6.073090  7.089435  4.746001
#
#                 ID1
# T0_CT_A01  4.635093
# T0_CT_A02  6.385429
# T0_CT_A03  7.135330
# T0_CT_A04  3.811132
# T0_CT_A05  0.000000

# %% [markdown]
# ## 標準化とPCA

# %%
# 遺伝子ごとに標準化
df_sc = (df - df.mean()) / df.std()
val = df_sc.values
df_sc.head()
# df_sc.var() # 分散１の確認
# Out:
#               MEF2C     MEF2D      MYF5     ANPEP    PDGFRA      MYOG
# T0_CT_A01 -0.843077 -0.547115  1.327219  0.967788 -0.460586 -0.513812  \
# T0_CT_A02 -1.121826 -0.547115 -0.146083  0.562279 -0.460586 -0.513812
# T0_CT_A03 -0.114496 -0.079870  1.712332  0.436286 -0.413953 -0.513812
# T0_CT_A04 -0.448213 -0.547115  1.075731  1.378423 -0.460586 -0.513812
# T0_CT_A05  0.832359 -0.547115  1.551508 -0.611103 -0.460586 -0.217714
#
#                TPM1      TPM2      MYH2      MYH3     NCAM1     TNNT1
# T0_CT_A01  0.196234  0.248401 -0.408523 -0.681096 -1.041276 -0.685003  \
# T0_CT_A02 -0.513661  0.191658 -0.408523 -0.681096 -0.417807 -0.685003
# T0_CT_A03  0.212180  0.503467 -0.408523 -0.660484  0.042454 -0.685003
# T0_CT_A04 -0.274231 -0.132403 -0.408523 -0.681096  0.532637 -0.685003
# T0_CT_A05  0.190665  0.099901  1.400278 -0.681096  0.525886  0.744502
#
#               TNNT2     TNNC1      CDK1      CDK2     CCNB1     CCNB2
# T0_CT_A01 -0.347875 -0.716216  1.204012 -0.260079  1.090370  0.892707  \
# T0_CT_A02 -1.424096 -0.716216  2.747613 -0.099861  2.052033  1.956294
# T0_CT_A03 -0.308647 -0.716216  2.600646  0.298922  1.591125  1.941569
# T0_CT_A04 -0.161094 -0.716216  2.435312  1.031213  2.776338  2.235217
# T0_CT_A05  0.340560 -0.716216  2.956376  1.929543  1.570929  1.885196
#
#               CCND1       ID1
# T0_CT_A01  0.923859  2.023012
# T0_CT_A02  0.976342  3.031366
# T0_CT_A03  0.473335  3.463377
# T0_CT_A04  0.079609  1.548335
# T0_CT_A05  0.557404 -0.647225

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=2).fit_transform(val)

plt.axis('equal')
plt.scatter(pca[:, 0], pca[:, 1])
plt.title('PCA (2D)')
# Out:
# Text(0.5, 1.0, 'PCA (2D)')

# %% [markdown]
# ## 標準化後の値の保存

# %%
genes_dict = {}
for gene in genes:
    gene_list = df_sc[gene].to_list()  # 各列をリストに変換
    genes_dict[gene] = gene_list # 列名をキーとし、配列を値として辞書に追加

# %% [markdown]
# ## 細胞サンプルの日付ラベルの取得

# %%
day_label = [0 for i in range(96)]
for i in range(96):
    day_label.append(1)
for i in range(96):
    day_label.append(2)
for i in range(84):
    day_label.append(3)
len(day_label)
# Out:
# 372

# %% [markdown]
# ## Kepler Mapper

# %%
# !git clone https://github.com/MLWave/kepler-mapper
# !cd kepler-mapper
# !pip install -e .

# %% [markdown]
# kepler-mapperフォルダ内のkmapperフォルダだけこのJupyter Notebookと同じディレクトリに取り出す．そして，kmapper2にフォルダ名を変更して，visuals.py上方のcolorscale_defaultと下方のdef _size_node(member_ids)を編集する．

# %%
import kmapper2 as km 
from kmapper2.plotlyviz import plotlyviz
import sklearn

mapper = km.KeplerMapper(verbose=0)

# %% [markdown]
# ### mappertools
# https://github.com/emerson-escolar/mappertools

# %%
# !pip install mappertools-0.3.8.tar
import mappertools.mapper.hierarchical_clustering as hc

# %% [markdown]
# フィルター関数・レンズ：PCA（２次元） ※井元先生推奨
# 被覆の数：10
# 被覆の重なり：50％ ※井元先生推奨
# クラスタリング：階層的クラスタリング（単連結法/最短距離法），１つ目のギャップ検出 ※井元先生推奨

# %%
lens = pca
simplicial_complex = mapper.map(lens, X=val,
                                cover=km.Cover(n_cubes=10, perc_overlap=0.5),
                                clusterer=hc.HeuristicHierarchical(heuristic='firstgap'))
# Out:
# Clustering using: Hierarchical clustering with single linkage and firstgap heuristic.
# 2 clusters detected in 17 points
# 1 clusters detected in 25 points
# 1 clusters detected in 20 points
# 13 clusters detected in 14 points
# 1 clusters detected in 10 points
# 1 clusters detected in 12 points
# 2 clusters detected in 12 points
# 2 clusters detected in 8 points
# 1 clusters detected in 5 points
# 1 clusters detected in 2 points
# 2 clusters detected in 45 points
# 1 clusters detected in 73 points
# 6 clusters detected in 45 points
# 1 clusters detected in 24 points
# 1 clusters detected in 21 points
# 2 clusters detected in 17 points
# 3 clusters detected in 21 points
# 1 clusters detected in 18 points
# 2 clusters detected in 9 points
# 3 clusters detected in 5 points
# 2 clusters detected in 38 points
# 1 clusters detected in 73 points
# 1 clusters detected in 53 points
# 3 clusters detected in 30 points
# 3 clusters detected in 23 points
# 3 clusters detected in 17 points
# 2 clusters detected in 18 points
# 8 clusters detected in 16 points
# 1 clusters detected in 10 points
# 1 clusters detected in 5 points
# 1 clusters detected in 14 points
# 3 clusters detected in 41 points
# 1 clusters detected in 51 points
# 1 clusters detected in 35 points
# 2 clusters detected in 17 points
# 2 clusters detected in 13 points
# 5 clusters detected in 8 points
# 1 clusters detected in 3 points
# 1 clusters detected in 5 points
# 1 clusters detected in 3 points
# 3 clusters detected in 7 points
# 4 clusters detected in 29 points
# 1 clusters detected in 52 points
# 1 clusters detected in 44 points
# 2 clusters detected in 17 points
# 2 clusters detected in 5 points
# 1 clusters detected in 2 points
# 1 clusters detected in 16 points
# 2 clusters detected in 43 points
# 2 clusters detected in 39 points
# 12 clusters detected in 13 points
# 1 clusters detected in 2 points
# 1 clusters detected in 2 points
# 1 clusters detected in 2 points
# 3 clusters detected in 7 points
# 3 clusters detected in 28 points
# 2 clusters detected in 26 points
# 2 clusters detected in 10 points
# 2 clusters detected in 7 points
# 1 clusters detected in 2 points
# 1 clusters detected in 2 points
# 1 clusters detected in 2 points
# 1 clusters detected in 3 points
# 4 clusters detected in 24 points
# 1 clusters detected in 29 points
# 1 clusters detected in 12 points
# 2 clusters detected in 6 points
# 1 clusters detected in 3 points
# 2 clusters detected in 4 points
# 2 clusters detected in 25 points
# 2 clusters detected in 34 points
# 11 clusters detected in 16 points
# 1 clusters detected in 3 points
# 1 clusters detected in 2 points
# 3 clusters detected in 13 points
# 2 clusters detected in 19 points
# 8 clusters detected in 11 points
# 1 clusters detected in 3 points

# %% [markdown]
# ## Mapperグラフを出力
# カラースケール：https://colorbrewer2.org/#type=diverging&scheme=Spectral&n=11

# %%
none= [0 for i in range(df_sc.shape[0])]
_ = mapper.visualize(
        simplicial_complex,
        title='none',
        path_html='./output/none.html',
        color_values=none,
        color_function_name='none'
    )

# %% [markdown]
# ### 細胞サンプルの取得日で色付け

# %%
_ = mapper.visualize(
        simplicial_complex,
        title='day',
        path_html='./output/day.html',
        color_values=day_label,
        color_function_name='day_label'
    )

# %% [markdown]
# ### 各遺伝子の発現量で色付け

# %%
for gene in genes:
    _ = mapper.visualize(
        simplicial_complex,
        title=gene,
        path_html='./output/' + gene + '.html',
        color_values=genes_dict[gene],
        color_function_name=gene
    )
