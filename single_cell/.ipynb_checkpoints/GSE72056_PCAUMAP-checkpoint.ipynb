# %% [markdown]
# # GSE72056-PCA/UMAP
# 良性腫瘍と悪性腫瘍を含むデータセットに対してPCAとUMAPを適用し，可視化する．

# %% [markdown]
# ## 読み込み

# %%
import numpy as np
import pandas as pd
import scanpy as sc
import matplotlib.pyplot as plt

# %%
data = pd.read_table('GSE72056_melanoma_single_cell_revised_v2.txt', index_col=0) 
print(data.shape)
data.head()
# 遺伝子×細胞
# Out:
# (23689, 4645)
#                                                     Cy72_CD45_H02_S758_comb
# Cell
# tumor                                                               72.0000  \
# malignant(1=no,2=yes,0=unresolved)                                   1.0000
# non-malignant cell type (1=T,2=B,3=Macro.4=Endo...                   2.0000
# C9orf152                                                             0.0000
# RPS11                                                                9.2172
#
#                                                     CY58_1_CD45_B02_S974_comb
# Cell
# tumor                                                                 58.0000  \
# malignant(1=no,2=yes,0=unresolved)                                     1.0000
# non-malignant cell type (1=T,2=B,3=Macro.4=Endo...                     1.0000
# C9orf152                                                               0.0000
# RPS11                                                                  8.3745
#
#                                                     Cy71_CD45_D08_S524_comb
# Cell
# tumor                                                                71.000  \
# malignant(1=no,2=yes,0=unresolved)                                    2.000
# non-malignant cell type (1=T,2=B,3=Macro.4=Endo...                    0.000
# C9orf152                                                              0.000
# RPS11                                                                 9.313
#
#                                                     Cy81_FNA_CD45_B01_S301_comb
# Cell
# tumor                                                                   81.0000  \
# malignant(1=no,2=yes,0=unresolved)                                       2.0000
# non-malignant cell type (1=T,2=B,3=Macro.4=Endo...                       0.0000
# C9orf152                                                                 0.0000
# RPS11                                                                    7.8876
#
#                                                     Cy80_II_CD45_B07_S883_comb
# Cell
# tumor                                                                  80.0000  \
# malignant(1=no,2=yes,0=unresolved)                                      2.0000
# non-malignant cell type (1=T,2=B,3=Macro.4=Endo...                      0.0000
# C9orf152                                                                0.0000
# RPS11                                                                   8.3291
#
#                                                     Cy81_Bulk_CD45_B10_S118_comb
# Cell
# tumor                                                                    81.0000  \
# malignant(1=no,2=yes,0=unresolved)                                        2.0000
# non-malignant cell type (1=T,2=B,3=Macro.4=Endo...                        0.0000
# C9orf152                                                                  0.0000
# RPS11                                                                     7.8336
#
#                                                     Cy72_CD45_D09_S717_comb
# Cell
# tumor                                                               72.0000  \
# malignant(1=no,2=yes,0=unresolved)                                   1.0000
# non-malignant cell type (1=T,2=B,3=Macro.4=Endo...                   1.0000
# C9orf152                                                             0.0000
# RPS11                                                                8.3737
#
#                                                     Cy74_CD45_A03_S387_comb
# Cell
# tumor                                                               74.0000  \
# malignant(1=no,2=yes,0=unresolved)                                   1.0000
# non-malignant cell type (1=T,2=B,3=Macro.4=Endo...                   1.0000
# C9orf152                                                             0.0000
# RPS11                                                                8.1338
#
#                                                     Cy71_CD45_B05_S497_comb
# Cell
# tumor                                                               71.0000  \
# malignant(1=no,2=yes,0=unresolved)                                   2.0000
# non-malignant cell type (1=T,2=B,3=Macro.4=Endo...                   0.0000
# C9orf152                                                             0.0000
# RPS11                                                                8.4373
#
#                                                     Cy80_II_CD45_C09_S897_comb
# Cell
# tumor                                                                  80.0000  \
# malignant(1=no,2=yes,0=unresolved)                                      2.0000
# non-malignant cell type (1=T,2=B,3=Macro.4=Endo...                      0.0000
# C9orf152                                                                0.0000
# RPS11                                                                   7.5968
#
#                                                     ...
# Cell                                                ...
# tumor                                               ...  \
# malignant(1=no,2=yes,0=unresolved)                  ...
# non-malignant cell type (1=T,2=B,3=Macro.4=Endo...  ...
# C9orf152                                            ...
# RPS11                                               ...
#
#                                                     CY75_1_CD45_CD8_7__S265_comb
# Cell
# tumor                                                                       75.0  \
# malignant(1=no,2=yes,0=unresolved)                                           1.0
# non-malignant cell type (1=T,2=B,3=Macro.4=Endo...                           1.0
# C9orf152                                                                     0.0
# RPS11                                                                        0.0
#
#                                                     CY75_1_CD45_CD8_3__S127_comb
# Cell
# tumor                                                                    75.0000  \
# malignant(1=no,2=yes,0=unresolved)                                        1.0000
# non-malignant cell type (1=T,2=B,3=Macro.4=Endo...                        1.0000
# C9orf152                                                                  0.0000
# RPS11                                                                     7.8639
#
#                                                     CY75_1_CD45_CD8_1__S61_comb
# Cell
# tumor                                                                   75.0000  \
# malignant(1=no,2=yes,0=unresolved)                                       1.0000
# non-malignant cell type (1=T,2=B,3=Macro.4=Endo...                       1.0000
# C9orf152                                                                 0.0000
# RPS11                                                                    5.8505
#
#                                                     CY75_1_CD45_CD8_1__S12_comb
# Cell
# tumor                                                                  75.00000  \
# malignant(1=no,2=yes,0=unresolved)                                      1.00000
# non-malignant cell type (1=T,2=B,3=Macro.4=Endo...                      1.00000
# C9orf152                                                                0.00000
# RPS11                                                                   0.62639
#
#                                                     CY75_1_CD45_CD8_1__S25_comb
# Cell
# tumor                                                                   75.0000  \
# malignant(1=no,2=yes,0=unresolved)                                       1.0000
# non-malignant cell type (1=T,2=B,3=Macro.4=Endo...                       1.0000
# C9orf152                                                                 0.0000
# RPS11                                                                    6.2734
#
#                                                     CY75_1_CD45_CD8_7__S223_comb
# Cell
# tumor                                                                    75.0000  \
# malignant(1=no,2=yes,0=unresolved)                                        1.0000
# non-malignant cell type (1=T,2=B,3=Macro.4=Endo...                        1.0000
# C9orf152                                                                  0.0000
# RPS11                                                                     5.4889
#
#                                                     CY75_1_CD45_CD8_1__S65_comb
# Cell
# tumor                                                                   75.0000  \
# malignant(1=no,2=yes,0=unresolved)                                       1.0000
# non-malignant cell type (1=T,2=B,3=Macro.4=Endo...                       1.0000
# C9orf152                                                                 0.0000
# RPS11                                                                    4.9262
#
#                                                     CY75_1_CD45_CD8_1__S93_comb
# Cell
# tumor                                                                   75.0000  \
# malignant(1=no,2=yes,0=unresolved)                                       1.0000
# non-malignant cell type (1=T,2=B,3=Macro.4=Endo...                       1.0000
# C9orf152                                                                 0.0000
# RPS11                                                                    7.0958
#
#                                                     CY75_1_CD45_CD8_1__S76_comb
# Cell
# tumor                                                                    75.000  \
# malignant(1=no,2=yes,0=unresolved)                                        1.000
# non-malignant cell type (1=T,2=B,3=Macro.4=Endo...                        1.000
# C9orf152                                                                  0.000
# RPS11                                                                     3.997
#
#                                                     CY75_1_CD45_CD8_7__S274_comb
# Cell
# tumor                                                                    75.0000
# malignant(1=no,2=yes,0=unresolved)                                        1.0000
# non-malignant cell type (1=T,2=B,3=Macro.4=Endo...                        0.0000
# C9orf152                                                                  0.0000
# RPS11                                                                     3.9897
#
# [5 rows x 4645 columns]

# %%
df = data.drop(['tumor', 'malignant(1=no,2=yes,0=unresolved)', 'non-malignant cell type (1=T,2=B,3=Macro.4=Endo.,5=CAF;6=NK)'], 
          axis=0) # 行（遺伝子）を削除
print(df.shape)
df.head()
# Out:
# (23686, 4645)
#           Cy72_CD45_H02_S758_comb  CY58_1_CD45_B02_S974_comb
# Cell
# C9orf152                   0.0000                     0.0000  \
# RPS11                      9.2172                     8.3745
# ELMO2                      0.0000                     0.0000
# CREB3L1                    0.0000                     0.0000
# PNMA1                      0.0000                     0.0000
#
#           Cy71_CD45_D08_S524_comb  Cy81_FNA_CD45_B01_S301_comb
# Cell
# C9orf152                   0.0000                       0.0000  \
# RPS11                      9.3130                       7.8876
# ELMO2                      2.1263                       0.0000
# CREB3L1                    0.0000                       0.0000
# PNMA1                      0.0000                       0.0000
#
#           Cy80_II_CD45_B07_S883_comb  Cy81_Bulk_CD45_B10_S118_comb
# Cell
# C9orf152                      0.0000                        0.0000  \
# RPS11                         8.3291                        7.8336
# ELMO2                         0.0000                        0.7740
# CREB3L1                       0.0000                        0.0000
# PNMA1                         0.0000                        0.0000
#
#           Cy72_CD45_D09_S717_comb  Cy74_CD45_A03_S387_comb
# Cell
# C9orf152                   0.0000                   0.0000  \
# RPS11                      8.3737                   8.1338
# ELMO2                      0.0000                   0.0000
# CREB3L1                    0.0000                   0.0000
# PNMA1                      0.0000                   0.0000
#
#           Cy71_CD45_B05_S497_comb  Cy80_II_CD45_C09_S897_comb  ...
# Cell                                                           ...
# C9orf152                   0.0000                     0.00000  ...  \
# RPS11                      8.4373                     7.59680  ...
# ELMO2                      0.0000                     0.38294  ...
# CREB3L1                    0.0000                     0.00000  ...
# PNMA1                      0.0000                     2.51420  ...
#
#           CY75_1_CD45_CD8_7__S265_comb  CY75_1_CD45_CD8_3__S127_comb
# Cell
# C9orf152                           0.0                        0.0000  \
# RPS11                              0.0                        7.8639
# ELMO2                              0.0                        0.0000
# CREB3L1                            0.0                        0.0000
# PNMA1                              0.0                        0.0000
#
#           CY75_1_CD45_CD8_1__S61_comb  CY75_1_CD45_CD8_1__S12_comb
# Cell
# C9orf152                       0.0000                      0.00000  \
# RPS11                          5.8505                      0.62639
# ELMO2                          3.1572                      4.79320
# CREB3L1                        0.0000                      0.00000
# PNMA1                          0.0000                      0.00000
#
#           CY75_1_CD45_CD8_1__S25_comb  CY75_1_CD45_CD8_7__S223_comb
# Cell
# C9orf152                       0.0000                        0.0000  \
# RPS11                          6.2734                        5.4889
# ELMO2                          0.0000                        0.0000
# CREB3L1                        0.0000                        0.0000
# PNMA1                          0.0000                        0.0000
#
#           CY75_1_CD45_CD8_1__S65_comb  CY75_1_CD45_CD8_1__S93_comb
# Cell
# C9orf152                       0.0000                       0.0000  \
# RPS11                          4.9262                       7.0958
# ELMO2                          5.5296                       0.0000
# CREB3L1                        0.0000                       0.0000
# PNMA1                          0.0000                       0.0000
#
#           CY75_1_CD45_CD8_1__S76_comb  CY75_1_CD45_CD8_7__S274_comb
# Cell
# C9orf152                        0.000                        0.0000
# RPS11                           3.997                        3.9897
# ELMO2                           0.000                        0.0000
# CREB3L1                         0.000                        0.0000
# PNMA1                           0.000                        0.0000
#
# [5 rows x 4645 columns]

# %% [markdown]
# 最初の3行を削除すると，23686個の遺伝子になる．

# %%
malignant_label = np.array(data.iloc[1, :].to_list()) # 0から数えて1行目（悪性ラベル）を抽出
malignant_label
# Out:
# array([1., 1., 2., ..., 1., 1., 1.])

# %%
tpm = df.values.T # 値のみ転置
tpm
# Out:
# array([[0.    , 9.2172, 0.    , ..., 0.    , 2.6638, 0.    ],
#        [0.    , 8.3745, 0.    , ..., 0.    , 6.9901, 0.    ],
#        [0.    , 9.313 , 2.1263, ..., 3.8777, 1.6126, 0.    ],
#        ...,
#        [0.    , 7.0958, 0.    , ..., 0.    , 1.9615, 0.    ],
#        [0.    , 3.997 , 0.    , ..., 0.    , 7.1918, 0.    ],
#        [0.    , 3.9897, 0.    , ..., 5.2398, 6.1588, 0.    ]])

# %% [markdown]
# 行が細胞，列が遺伝子になった．

# %%
tpm.shape
# Out:
# (4645, 23686)

# %% [markdown]
# ## 遺伝子の抽出

# %%
tpm_mean = np.mean(tpm, axis=0) # 列ごと（遺伝子ごと）に平均発現量を計算
tpm_mean_sort = np.sort(tpm_mean)[::-1] # tpm_meanを大きい順にソート

tpm_var = np.var(tpm, axis=0) # 列ごと（遺伝子ごと）に発現量の分散を計算
tpm_var_sort = np.sort(tpm_var)[::-1] # tpm_varを大きい順にソート

# %% [markdown]
# 平均／分散発現量が大きい方から7000個の遺伝子を抽出（配列の6999番まで）

# %%
# 閾値
print(tpm_mean_sort[6999]) 
print(tpm_var_sort[6999])
# Out:
# 0.507662716275565
# 1.1790234203006325

# %%
c = (tpm_mean >= tpm_mean_sort[6999]) & (tpm_var >= tpm_var_sort[6999])
G = tpm[:,c]
G.shape
# Out:
# (4645, 6066)

# %% [markdown]
# ## PCA，UMAP（２次元）

# %%
from sklearn.decomposition import PCA
data_PCA = PCA(n_components=2).fit_transform(G)

# %%
import umap
data_UMAP = umap.UMAP(n_components=2, random_state=0, n_neighbors=15).fit_transform(G)

# %% [markdown]
# ## クラスタを見る
#
# 悪性ラベルで色付け
# 0：不明，1：良性，2：悪性

# %%
df_PCA = pd.DataFrame(data_PCA)
df_PCA['label'] = malignant_label
df_PCA
# Out:
#               0          1  label
# 0    -51.951927 -32.342695    1.0
# 1    -36.598450  11.633383    1.0
# 2     54.276151  -9.089401    2.0
# 3     86.697487  11.468895    2.0
# 4     98.903976  14.461162    2.0
# ...         ...        ...    ...
# 4640 -27.733962  23.376570    1.0
# 4641 -38.219817  22.165624    1.0
# 4642 -29.714171  20.769966    1.0
# 4643 -28.145755  25.184587    1.0
# 4644 -19.915063  46.454309    1.0
#
# [4645 rows x 3 columns]

# %%
colors = ['#5e4fa2', '#fee08b', '#9e0142']
labels = [0, 1, 2]
captions = ['不明', '良性', '悪性']

# %%
import japanize_matplotlib # 日本語対応
for color, label, caption in zip(colors, labels, captions):
    tmp = df_PCA.loc[df_PCA['label'] == label]
    plt.scatter(tmp[0], tmp[1], color=color, label=caption)
plt.legend()

# %%
df_UMAP = pd.DataFrame(data_UMAP)
df_UMAP['label'] = malignant_label
df_UMAP
# Out:
#               0         1  label
# 0      2.302265  2.429088    1.0
# 1      1.166400 -0.017455    1.0
# 2     10.096863  2.758172    2.0
# 3     12.706478  1.680048    2.0
# 4     10.865952  1.602636    2.0
# ...         ...       ...    ...
# 4640   1.540978  0.100675    1.0
# 4641   1.651065  0.152750    1.0
# 4642   1.501864  0.110750    1.0
# 4643   1.479035  0.135563    1.0
# 4644   1.285314  0.214230    1.0
#
# [4645 rows x 3 columns]

# %%
import japanize_matplotlib # 日本語対応
for color, label, caption in zip(colors, labels, captions):
    tmp = df_UMAP.loc[df_UMAP['label'] == label]
    plt.scatter(tmp[0], tmp[1], color=color, label=caption)
plt.legend()
